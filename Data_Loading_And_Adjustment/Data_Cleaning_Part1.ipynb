# %%
import pandas as pd

# %% [markdown]
# # World Bank Data Cleaning

# %%
worldbankdf = pd.read_csv("DatabankWide.csv")

# %% [markdown]
# Since variable naming is currently very long, we will shorten all the relevant variables

# %%
worldbankdf.rename(columns={"Country name":"country","Country code":"country_code","Year":"year","Adult populaiton":"adult_pop","Region":"region","Income group":"income_group","Account (% age 15+)":"account_pct","Borrowed any money (% age 15+)":"borrowed_any_pct","Borrowed any money from a formal financial institution or using a mobile money account (% age 15+)":"borrowed_formal_mobile_pct","Borrowed any money using a mobile money account (% age 15+)":"borrowed_mobile_pct","Borrowed for education or school fees (% age 15+)":"borrowed_for_edu_pct","Borrowed for health or medical purposes (% age 15+)":"borrowed_for_health_pct","Borrowed from a formal financial institution (% age 15+)":"borrowed_from_formal_pct","Can use a mobile money account without help from anyone, including a mobile money agent (% age 15+)":"mobile_money_indep_pct","Can use a mobile money account without help from anyone, including a mobile money agent (% with a mobile money account, age 15+)":"mobile_money_indep_mobile_acc_pct","Can use account at a bank or financial institution without help if opened (% without an account, age 15+)":"bank_account_indep_noacct_pct","Coming up with emergency funds in 7 days: possible (% age 15+)":"emergency_funds_possible_pct","Coming up with emergency funds in 7 days: possible and not difficult (% age 15+)":"emergency_funds_possible_notdiff_pct","Coming up with emergency funds in 7 days: possible and not difficult or somewhat difficult (% age 15+)":"emergency_funds_possible_somewhat_diff_pct","Financial institution account (% age 15+)":"fin_account_pct","Has access to the Internet (% age 15+)":"internet_access_pct","Has an outstanding housing loan (% age 15+)":"outstanding_housing_loan_pct","Made a cash payment upon delivery for an online purchase (% age 15+)":"cash_delivery_payment_pct","Made a deposit (% with a financial institution account, age 15+)":"deposit_has_fin_account_pct","Made a digital online merchant payment for an online purchase (% age 15+)":"digital_payment_merchant_online_pct","Made a digital online payment for an online purchase (% of internet purchasers, age 15+)":"digital_payment_from_internet_users_pct","Made a digital payment (% age 15+)":"digital_payment_made_pct","Made or received a digital payment (% age 15+)":"digital_payment_made_received_pct","Main mode of withdrawal: ATM (% with a financial institution account, age 15+)":"withdrawal_atm_with_acc_pct","Main mode of withdrawal: bank teller (% with a financial institution account, age 15+)":"withdrawal_teller_with_acc_pct","Most worrying financial issue: money for old age (% age 15+)":"worry_money_old_age_pct","Most worrying financial issue: money to pay for monthly expenses or bills (% age 15+)":"worry_money_expenses_pct","Most worrying financial issue: paying for medical costs in case of a serious illness or accident (% age 15+)":"worry_money_medical_pct","Most worrying financial issue: paying school or education fees (% age 15+)":"worry_money_education_pct","No account because financial institutions are too far away (% age 15+)":"no_acct_far_pct","No account because financial institutions are too far away (% without an account, age 15+)":"no_acct_far_without_acc_pct","No account because financial services are too expensive (% age 15+)":"no_acct_expensive_pct","No account because financial services are too expensive (% without an account, age 15+)":"no_acct_expensive_without_acc_pct","No account because of a lack of necessary documentation (% age 15+)":"no_acct_docs_pct","No account because of a lack of necessary documentation (% without an account, age 15+)":"no_acct_docs_without_acc_pct","No account because of a lack of trust in financial institutions (% age 15+)":"no_acct_trust_pct","No account because of a lack of trust in financial institutions (% without an account, age 15+)":"no_acct_trust_without_acc_pct","No account because of insufficient funds (% age 15+)":"no_acct_funds_pct","No account because of insufficient funds (% without an account, age 15+)":"no_acct_funds_without_acc_pct","No account because of religious reasons (% age 15+)":"no_acct_religious_pct","No account because of religious reasons (% without an account, age 15+)":"no_acct_religious_without_acc_pct","No account because someone in the family has one (% age 15+)":"no_acct_family_pct","No account because someone in the family has one (% without an account, age 15+)":"no_acct_family_without_acc_pct","Own a mobile phone (% age 15+)":"own_mobile_pct","Owns a debit or credit card (% age 15+)":"own_card_pct","Paid school fees (% age 15+)":"paid_school_fees_pct","Received wages (% age 15+)":"received_wages_pct","Received wages into an account: paid higher than expected fees (% age 15+)":"received_wages_acct_fees_pct","Received wages into an account: paid higher than expected fees (% who received wages into an account, age 15+)":"received_wages_acct_fees_wage_receivers_pct","Received wages: into an account (% age 15+)":"received_wages_acc_pct","Received wages: into an account (% of wage recipients, age 15+)":"received_wages_acc_wage_receivers_pct","Received wages: in cash only (% age 15+)":"received_wages_cash_pct","Received wages: in cash only (% of wage recipients, age 15+)":"received_wages_cash_wage_receivers_pct","Received wages: into a financial institution account (% age 15+)":"received_wages_fin_account_pct","Received wages: into a financial institution account (% of wage recipients, age 15+)":"received_wages_fin_account_wage_receivers_pct","Received wages: through a mobile phone (% age 15+)":"received_wages_mobile_wage_receivers_pct","Received wages: through a mobile phone (% of wage recipients, age 15+)":"received_wages_mobile_pct","Received wages: to a card (% age 15+)":"received_wages_card_pct","Received wages: to a card (% of wage recipients, age 15+)":"received_wages_card_wage_receivers_pct","Saved at a financial institution (% age 15+)":"saved_fin_account_pct","Saved at a financial institution or using a mobile money account (% age 15+)":"saved_fin_account_or_mobile_pct","Saved for education or school fees (% age 15+)":"saved_education_pct","Store money using a financial institution (% age 15+)":"store_money_fin_account_pct","Store money using a financial institution (% with a financial institution account, age 15+)":"store_money_fin_account_with_acc_pct","Store money using a financial institution or a mobile money account (% age 15+)":"store_money_fin_account_or_mobile_account_pct","Store money using a financial institution or a mobile money account (% with an account,  age 15+)":"store_money_fin_account_or_mobile_account_with_acc_pct","Store money using a mobile money account (% age 15+)":"store_money_mobile_pct","Store money using a mobile money account (% with a mobile money account acount, age 15+)":"store_money_mobile_with_acc_pct","Used a debit or credit card: in-store (% who use a credit or debit card, age 15+)":"used_card_instore_card_users_pct","Used a mobile phone or the internet to access a financial institution account (% age 15+)":"used_phone_internet_access_account_pct","Used a mobile phone or the internet to access a financial institution account (% with a financial institution account, age 15+)":"used_phone_internet_access_account_with_acc_pct","Used a mobile phone or the internet to buy something online (% age 15+)":"used_phone_or_internet_buy_pct","Used a mobile phone or the internet to pay bills (% age 15+)":"used_phone_or_internet_bills_pct","Used a mobile phone or the internet to send money (% age 15+)":"used_phone_or_internet_send_money_pct","Used checks to make payments (% age 15+)":"used_checks_payment_pct","Worried about not being able to pay for medical costs in case of a serious illness or accident: not worried at all (% age 15+)":"worry_medical_not_worried_pct","Worried about not being able to pay for medical costs in case of a serious illness or accident: somewhat worried (% age 15+)":"worry_medical_somewhat_worried_pct","Worried about not being able to pay for medical costs in case of a serious illness or accident: very worried (% age 15+)":"worry_medical_very_worried_pct","Worried about not being able to pay school fees or fees for education: not worried at all (% age 15+)":"worry_school_not_worried_pct","Worried about not being able to pay school fees or fees for education: somewhat worried (% age 15+)":"worry_school_somewhat_worried_pct","Worried about not being able to pay school fees or fees for education: very worried (% age 15+)":"worry_school_very_worried_pct","Worried about not having enough money for monthly expenses or bills: not worried at all (% age 15+)":"worry_expenses_not_worried_pct","Worried about not having enough money for monthly expenses or bills: somewhat worried (% age 15+)":"worry_expenses_very_worried_pct","Worried about not having enough money for monthly expenses or bills: very worried (% age 15+)":"worry_expenses_somewhat_worried_pct","Worried about not having enough money for old age: not worried at all (% age 15+)":"worry_old_age_not_worried_pct","Worried about not having enough money for old age: somewhat worried (% age 15+)":"worry_old_age_somewhat_worried_pct","Worried about not having enough money for old age: very worried (% age 15+)":"worry_old_age_very_worried_pct"}
, inplace=True)
worldbankdf.head()
# Out:
#        country country_code  year   adult_pop  \
# 0  Afghanistan          AFG  2011  15124473.0
# 1  Afghanistan          AFG  2014  17300802.0
# 2  Afghanistan          AFG  2017  19718214.0
# 3  Afghanistan          AFG  2021  22647496.0
# 4      Albania          ALB  2011   2258900.0
#
#                                           region         income_group  \
# 0                                     South Asia           Low income
# 1                                     South Asia           Low income
# 2                                     South Asia           Low income
# 3                                     South Asia           Low income
# 4  Europe & Central Asia (excluding high income)  Upper middle income
#
#   account_pct fin_account_pct  \
# 0          9%              9%
# 1         10%             10%
# 2         15%             15%
# 3         10%             10%
# 4         28%             28%
#
# ...

# %% [markdown]
# Now we will only keep these variables and drop all the rest. Note: Two columns are creating issues: internet_access_pct, used_phone_internet_access_account_pct

# %%
columns_to_keep = [
    'country', 
    'country_code', 
    'year', 
    'adult_pop', 
    'region', 
    'income_group',
    'account_pct',
    'borrowed_any_pct',
    'borrowed_formal_mobile_pct',
    'borrowed_mobile_pct',
    'borrowed_for_edu_pct',
    'borrowed_for_health_pct',
    'borrowed_from_formal_pct',
    'mobile_money_indep_pct',
    'mobile_money_indep_mobile_acc_pct',
    'bank_account_indep_noacct_pct',
    'emergency_funds_possible_pct',
    'emergency_funds_possible_notdiff_pct',
    'emergency_funds_possible_somewhat_diff_pct',
    'fin_account_pct',
    'outstanding_housing_loan_pct',
    'cash_delivery_payment_pct',
    'deposit_has_fin_account_pct',
    'digital_payment_merchant_online_pct',
    'digital_payment_from_internet_users_pct',
    'digital_payment_made_pct',
    'digital_payment_made_received_pct',
    'withdrawal_atm_with_acc_pct',
    'withdrawal_teller_with_acc_pct',
    'worry_money_old_age_pct',
    'worry_money_expenses_pct',
    'worry_money_medical_pct',
    'worry_money_education_pct',
    'no_acct_far_pct',
    'no_acct_far_without_acc_pct',
    'no_acct_expensive_pct',
    'no_acct_expensive_without_acc_pct',
    'no_acct_docs_pct',
    'no_acct_docs_without_acc_pct',
    'no_acct_trust_pct',
    'no_acct_trust_without_acc_pct',
    'no_acct_funds_pct',
    'no_acct_funds_without_acc_pct',
    'no_acct_religious_pct',
    'no_acct_religious_without_acc_pct',
    'no_acct_family_pct',
    'no_acct_family_without_acc_pct',
    'own_mobile_pct',
    'own_card_pct',
    'paid_school_fees_pct',
    'received_wages_pct',
    'received_wages_acct_fees_pct',
    'received_wages_acct_fees_wage_receivers_pct',
    'received_wages_acc_pct',
    'received_wages_acc_wage_receivers_pct',
    'received_wages_cash_pct',
    'received_wages_cash_wage_receivers_pct',
    'received_wages_fin_account_pct',
    'received_wages_fin_account_wage_receivers_pct',
    'received_wages_mobile_wage_receivers_pct',
    'received_wages_mobile_pct',
    'received_wages_card_pct',
    'received_wages_card_wage_receivers_pct',
    'saved_fin_account_pct',
    'saved_fin_account_or_mobile_pct',
    'saved_education_pct',
    'store_money_fin_account_pct',
    'store_money_fin_account_with_acc_pct',
    'store_money_fin_account_or_mobile_account_pct',
    'store_money_fin_account_or_mobile_account_with_acc_pct',
    'store_money_mobile_pct',
    'store_money_mobile_with_acc_pct',
    'used_card_instore_card_users_pct',
    'used_phone_internet_access_account_with_acc_pct',
    'used_phone_or_internet_buy_pct',
    'used_phone_or_internet_bills_pct',
    'used_phone_or_internet_send_money_pct',
    'used_checks_payment_pct',
    'worry_medical_not_worried_pct',
    'worry_medical_somewhat_worried_pct',
    'worry_medical_very_worried_pct',
    'worry_school_not_worried_pct',
    'worry_school_somewhat_worried_pct',
    'worry_school_very_worried_pct',
    'worry_expenses_not_worried_pct',
    'worry_expenses_very_worried_pct',
    'worry_expenses_somewhat_worried_pct',
    'worry_old_age_not_worried_pct',
    'worry_old_age_somewhat_worried_pct',
    'worry_old_age_very_worried_pct',
]

# Keep only the specified columns
worldbankdf_clean = worldbankdf[columns_to_keep]
worldbankdf_clean
# Out:
#                                         country country_code  year  \
# 0                                   Afghanistan          AFG  2011
# 1                                   Afghanistan          AFG  2014
# 2                                   Afghanistan          AFG  2017
# 3                                   Afghanistan          AFG  2021
# 4                                       Albania          ALB  2011
# ..                                          ...          ...   ...
# 653  Sub-Saharan Africa (excluding high income)          SSA  2021
# 654                                       World          WLD  2011
# 655                                       World          WLD  2014
# 656                                       World          WLD  2017
# 657                                       World          WLD  2021
#
#         adult_pop                                         region  \
# 0    1.512447e+07                                     South Asia
# ...

# %% [markdown]
# We will now export this file

# %% [markdown]
# # ITU Data Cleaning

# %%
itudf = pd.read_csv("itu.csv", encoding='ISO-8859-1')

# %% [markdown]
# Since variable naming is currently very long, we will shorten all the relevant variables

# %%
itudf.rename(columns={"entityName":"country","dataYear":"year","Annual investment in telecommunication services":"investment_in_telecommunication_usd","Bitstream access service":"bitstream_access_service","Connecting and installing new devices":"skill_connecting_installing_devices","Creating electronic presentations with presentation software":"skill_creating_presentations","Desktop computer":"hh_own_desktop_computer_pct","Female":"skill_software_run_over_the_internet_female","Fibre":"mkt_structure_fibre","Finding, downloading, installing and configuring software":"skill_installing_software_pct","Fixed Wireless Broadband":"mkt_structure_fixed_wireless_broadband","Households with Internet access at home":"hh_with_internet_access_at_home_pct","Households with a computer":"hh_own_computer_pct","Individuals using a computer":"individuals_using_computer_pct","Individuals using a smart phone":"individuals_using_smart_phone_pct","Individuals using the Internet":"individuals_using_internet_pct","International bandwidth usage":"international_bandwidth_usage","Internet banking":"skill_internet_banking_pct","Laptop computer":"hh_own_computer_pct","Lit/equipped international bandwidth capacity":"international_bandwidth_capacity","Male":"skill_software_run_over_the_internet_male_pct","Mobile-broadband Internet traffic (within the country)":"mobile_broadband_internet_traffic_country","Number of Internet exchange points (IXPs)":"number_of_internet_exchange_points","Number of Internet service providers (ISPs)":"number_of_internet_service_providers","Participating in social networks":"skill_social_networks_pct","Rural":"skill_software_run_over_the_internet_rural_pct","SMS sent":"sms_sent","Sending e-mails with attached files":"skill_e_mails_attached_files_pct","Service activation time for fixed-broadband service":"service_activation_time_for_fixed_broadband_service","Tablet":"hh_own_tablet_pct","Transferring files between a computer and other devices":"skill_transferring_files_pct","Uploading self/user-created content to a website to be shared":"skill_uploading_content_pct","Urban":"skill_software_run_over_the_internet_urban_pct","Using basic arithmetic formula in a spreadsheet":"skill_arithmetic_formula_spreadsheet_pct","Using copy and paste tools within a document":"skill_copy_and_paste_pct","Using software run over the Internet for editing text documents, spreadsheets or presentations":"skill_software_run_over_the_internet_pct","Writing a computer program using a programming language":"skill_programming_pct",}
, inplace=True)
itudf.head()
# Out:
#        country  year investment_in_telecommunication_usd  \
# 0  Afghanistan  2000                                 NaN
# 1  Afghanistan  2001                                 NaN
# 2  Afghanistan  2002                                 NaN
# 3  Afghanistan  2003                                 NaN
# 4  Afghanistan  2004                                 NaN
#
#   bitstream_access_service  skill_connecting_installing_devices  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
#
#    skill_creating_presentations  hh_own_desktop_computer_pct  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# ...

# %% [markdown]
# Now we will only keep these relevant variables and drop the rest

# %%
columns_to_keep = ["country",
"year",
"investment_in_telecommunication_usd",
"bitstream_access_service",
"skill_connecting_installing_devices",
"skill_creating_presentations",
"hh_own_desktop_computer_pct",
"skill_software_run_over_the_internet_female",
"mkt_structure_fibre",
"skill_installing_software_pct",
"mkt_structure_fixed_wireless_broadband",
"hh_with_internet_access_at_home_pct",
"hh_own_computer_pct",
"individuals_using_computer_pct",
"individuals_using_smart_phone_pct",
"individuals_using_internet_pct",
"international_bandwidth_usage",
"skill_internet_banking_pct",
"hh_own_computer_pct",
"international_bandwidth_capacity",
"skill_software_run_over_the_internet_male_pct",
"mobile_broadband_internet_traffic_country",
"number_of_internet_exchange_points",
"number_of_internet_service_providers",
"skill_social_networks_pct",
"skill_software_run_over_the_internet_rural_pct",
"sms_sent",
"skill_e_mails_attached_files_pct",
"service_activation_time_for_fixed_broadband_service",
"hh_own_tablet_pct",
"skill_transferring_files_pct",
"skill_uploading_content_pct",
"skill_software_run_over_the_internet_urban_pct",
"skill_arithmetic_formula_spreadsheet_pct",
"skill_copy_and_paste_pct",
"skill_software_run_over_the_internet_pct",
"skill_programming_pct",
]

# Keep only the specified columns
itudf_clean = itudf[columns_to_keep]
itudf_clean.head()
# Out:
#        country  year investment_in_telecommunication_usd  \
# 0  Afghanistan  2000                                 NaN
# 1  Afghanistan  2001                                 NaN
# 2  Afghanistan  2002                                 NaN
# 3  Afghanistan  2003                                 NaN
# 4  Afghanistan  2004                                 NaN
#
#   bitstream_access_service  skill_connecting_installing_devices  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
#
#    skill_creating_presentations  hh_own_desktop_computer_pct  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# ...

# %% [markdown]
# # Meta Data Cleaning

# %%
import pandas as pd
metadf = pd.read_csv("Meta.csv", encoding='ISO-8859-1')

# %%
metadf.rename(columns={"Country":"country","Country Code":"country_code","Year":"year","1.1.1) Internet users":"internet_users_pct","1.1.2) Fixed-line broadband subscribers":"Fixed_line_broadband subscribers_pct","1.1.3) Mobile subscribers":"mobile_subscribers_pct","1.2.1) Average fixed broadband upload speed":"fixed_broadband_upload_speed","1.2.2) Average fixed broadband download speed":"fixed_broadband_download_speed","1.2.4) Average mobile upload speed":"mobile_upload_speed","1.2.5) Average mobile download speed":"mobile_download_speed","1.3.1) Network coverage (min. 2G)":"2G_coverage_pct","1.3.2) Network coverage (min. 3G)":"3G_coverage_pct","1.3.3) Network coverage (min. 4G)":"4G_coverage_pct","2.1.1) Smartphone cost (handset)":"smartphone_cost","2.1.2) Mobile phone cost (prepaid tariff)":"mobile_cost_prepaid","2.1.3) Mobile phone cost (postpaid tariff)":"mobile_cost_postpaid","2.1.4) Fixed-line monthly broadband cost":"fixed_broadband_cost","3.2.1) e-Finance content":"efinance_content","3.2.2) Value of e-finance":"efinance_value","4.1.1) Level of literacy":"literacy_pct","4.1.2) Educational attainment":"edu_attainment_pct","4.1.3) Support for digital literacy":"support_digital_literacy","BG1) Nominal GDP":"nominal_gdp","BG3) Urban population":"urban_population","BG4) GNI per capita":"gni_per_capita","BG5) GINI coefficient":"gini_coefficient","BG6) Population under the poverty line":"population_under_poverty_line_pct","BG9) Percentage of schools with Internet access":"schools_internet access_pct","BG10) Global Peace Index":"global_peace_index","BG15) Internet users (population)":"internet_users ","BG16) Offline population":"offline_population_pct","BG19) Internet users (percent of population)":"internet_users_pct","BG24) Total fixed line broadband subscribers":"total_fixed_broadband_subs",}
, inplace=True)

# %%
metadf.head()
# Out:
#      country country_code  year  internet_users_pct  \
# 0    Algeria          DZA  2017                31.9
# 1     Angola          AGO  2017                14.7
# 2  Argentina          ARG  2017                62.0
# 3  Australia          AUS  2017                85.9
# 4    Austria          AUT  2017                82.4
#
#    Fixed_line_broadband subscribers_pct  mobile_subscribers_pct  \
# 0                                  5.71                   108.8
# 1                                  0.55                    49.8
# 2                                 15.92                   143.6
# 3                                 28.53                   107.7
# 4                                 28.29                   155.2
#
#   1.1.4) Gender gap in internet access  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# ...

# %%
columns_to_keep = ["country",
"country_code",
"year",
"internet_users_pct",
"Fixed_line_broadband subscribers_pct",
"mobile_subscribers_pct",
"fixed_broadband_upload_speed",
"fixed_broadband_download_speed",
"mobile_upload_speed",
"mobile_download_speed",
"2G_coverage_pct",
"3G_coverage_pct",
"4G_coverage_pct",
"smartphone_cost",
"mobile_cost_prepaid",
"mobile_cost_postpaid",
"fixed_broadband_cost",
"efinance_content",
"efinance_value",
"literacy_pct",
"edu_attainment_pct",
"support_digital_literacy",
"nominal_gdp",
"urban_population",
"gni_per_capita",
"gini_coefficient",
"population_under_poverty_line_pct",
"schools_internet access_pct",
"global_peace_index",
"internet_users ",
"offline_population_pct",
"internet_users_pct",
"total_fixed_broadband_subs",
]

# Keep only the specified columns
metadf_clean = metadf[columns_to_keep]
metadf_clean
# Out:
#         country country_code  year  internet_users_pct  internet_users_pct  \
# 0       Algeria          DZA  2017                31.9                38.2
# 1        Angola          AGO  2017                14.7                12.4
# 2     Argentina          ARG  2017                62.0                68.0
# 3     Australia          AUS  2017                85.9                84.6
# 4       Austria          AUT  2017                82.4                83.9
# ..          ...          ...   ...                 ...                 ...
# 595  Uzbekistan          UZB  2022                93.6                71.1
# 596   Venezuela          VEN  2022                33.5                61.6
# 597     Vietnam          VNM  2022                76.4                70.3
# 598      Zambia          ZMB  2022                20.9                19.8
# 599    Zimbabwe          ZWE  2022                50.1                29.3
#
#      Fixed_line_broadband subscribers_pct  mobile_subscribers_pct  \
# ...

# %%
# Get unique list of countries from metadf
countries = metadf['country'].unique()

# Create a list of years from 2010 to the current year (if needed, adjust range)
years = list(range(2010, 2025))  # Adjust the end year as required

# Create a new DataFrame with all combinations of country and year
new_df = pd.MultiIndex.from_product([countries, years], names=['country', 'year']).to_frame(index=False)
new_df
# Out:
#        country  year
# 0      Algeria  2010
# 1      Algeria  2011
# 2      Algeria  2012
# 3      Algeria  2013
# 4      Algeria  2014
# ...        ...   ...
# 1495  Zimbabwe  2020
# 1496  Zimbabwe  2021
# 1497  Zimbabwe  2022
# 1498  Zimbabwe  2023
# 1499  Zimbabwe  2024
#
# [1500 rows x 2 columns]

# %%
merged_df = pd.merge(new_df, metadf_clean, on=['country', 'year'], how='left')
merged_df = pd.merge(merged_df, itudf_clean, on=['country', 'year'], how='left')
merged_df =pd.merge(merged_df, worldbankdf_clean, on=['country', 'year'], how='left')
merged_df.columns
# Out:
# Index(['country', 'year', 'country_code_x', 'internet_users_pct',
#        'internet_users_pct', 'Fixed_line_broadband subscribers_pct',
#        'mobile_subscribers_pct', 'fixed_broadband_upload_speed',
#        'fixed_broadband_download_speed', 'mobile_upload_speed',
#        ...
#        'worry_medical_very_worried_pct', 'worry_school_not_worried_pct',
#        'worry_school_somewhat_worried_pct', 'worry_school_very_worried_pct',
#        'worry_expenses_not_worried_pct', 'worry_expenses_very_worried_pct',
#        'worry_expenses_somewhat_worried_pct', 'worry_old_age_not_worried_pct',
#        'worry_old_age_somewhat_worried_pct', 'worry_old_age_very_worried_pct'],
#       dtype='object', length=160)

# %%
merged_df
# Out:
#        country  year country_code_x  internet_users_pct  internet_users_pct  \
# 0      Algeria  2010            NaN                 NaN                 NaN
# 1      Algeria  2011            NaN                 NaN                 NaN
# 2      Algeria  2012            NaN                 NaN                 NaN
# 3      Algeria  2013            NaN                 NaN                 NaN
# 4      Algeria  2014            NaN                 NaN                 NaN
# ...        ...   ...            ...                 ...                 ...
# 1495  Zimbabwe  2020            ZWE                30.3                27.1
# 1496  Zimbabwe  2021            ZWE                34.9                27.1
# 1497  Zimbabwe  2022            ZWE                50.1                29.3
# 1498  Zimbabwe  2023            NaN                 NaN                 NaN
# 1499  Zimbabwe  2024            NaN                 NaN                 NaN
#
# ...

# %%
merged_df.to_csv('merged_data_1.csv', index=False)
